% %%
run plot_gemm_m1p_k1p_n1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_gemm_m1p_k1p_n1p_clarksville.m' in file /code/experiment/results/plot_gemm_m1p_k1p_n1p_clarksville.m near line 53, column 1

% %%
run plot_gemv_m1p_n1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_gemv_m1p_n1p_clarksville.m' in file /code/experiment/results/plot_gemv_m1p_n1p_clarksville.m near line 53, column 1

% %%
run plot_symm_m1p_n1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_symm_m1p_n1p_clarksville.m' in file /code/experiment/results/plot_symm_m1p_n1p_clarksville.m near line 53, column 1

% %%
run plot_symv_m1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_symv_m1p_clarksville.m' in file /code/experiment/results/plot_symv_m1p_clarksville.m near line 53, column 1

% %%
run plot_syr2_m1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_syr2_m1p_clarksville.m' in file /code/experiment/results/plot_syr2_m1p_clarksville.m near line 53, column 1

% %%
run plot_syr2k_m1p_k1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_syr2k_m1p_k1p_clarksville.m' in file /code/experiment/results/plot_syr2k_m1p_k1p_clarksville.m near line 53, column 1

% %%
run plot_syr_m1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_syr_m1p_clarksville.m' in file /code/experiment/results/plot_syr_m1p_clarksville.m near line 53, column 1

% %%
run plot_syrk_m1p_k1p_clarksville
% Out:
% ...
% Some output formats are not available.
% ...
% Some output formats are not available.
% ...
% Some output formats are not available.
% ...
% GPL Ghostscript 9.19: **** Could not open the file figures/syrk_m1p_k1p_clarksville.pdf .

% %%
run plot_trmm_m1p_n1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_trmm_m1p_n1p_clarksville.m' in file /code/experiment/results/plot_trmm_m1p_n1p_clarksville.m near line 53, column 1

% %%
run plot_trmv_m1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_trmv_m1p_clarksville.m' in file /code/experiment/results/plot_trmv_m1p_clarksville.m near line 53, column 1

% %%
run plot_trsm_fusing_m1p_n1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 61 column 1
% error: called from '/code/experiment/results/plot_trsm_fusing_m1p_n1p_clarksville.m' in file /code/experiment/results/plot_trsm_fusing_m1p_n1p_clarksville.m near line 61, column 1

% %%
run plot_trsm_fusing_m1p_n1p_speedup_clarksville
% Out:
% ...
% 'export_fig' undefined near line 69 column 1
% error: called from '/code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m' in file /code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m near line 69, column 1

% %%
run plot_trsm_fusing_m1p_n1p_speedup_clarksville
% Out:
% ...
% 'export_fig' undefined near line 69 column 1
% error: called from '/code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m' in file /code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m near line 69, column 1

% %%
run plot_trsv_m1p_clarksville
% Out:
% ...
% 'export_fig' undefined near line 53 column 1
% error: called from '/code/experiment/results/plot_trsv_m1p_clarksville.m' in file /code/experiment/results/plot_trsv_m1p_clarksville.m near line 53, column 1
