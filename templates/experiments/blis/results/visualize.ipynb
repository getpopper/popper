% %%
run plot_gemm_m1p_k1p_n1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_gemm_m1p_k1p_n1p_clarksville.m' in file /code/experiment/results/plot_gemm_m1p_k1p_n1p_clarksville.m near line 50, column 1

% %%
run plot_gemv_m1p_n1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_gemv_m1p_n1p_clarksville.m' in file /code/experiment/results/plot_gemv_m1p_n1p_clarksville.m near line 50, column 1

% %%
run plot_symm_m1p_n1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_symm_m1p_n1p_clarksville.m' in file /code/experiment/results/plot_symm_m1p_n1p_clarksville.m near line 50, column 1

% %%
run plot_symv_m1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_symv_m1p_clarksville.m' in file /code/experiment/results/plot_symv_m1p_clarksville.m near line 50, column 1

% %%
run plot_syr2_m1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_syr2_m1p_clarksville.m' in file /code/experiment/results/plot_syr2_m1p_clarksville.m near line 50, column 1

% %%
run plot_syr2k_m1p_k1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_syr2k_m1p_k1p_clarksville.m' in file /code/experiment/results/plot_syr2k_m1p_k1p_clarksville.m near line 50, column 1

% %%
run plot_syr_m1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_syr_m1p_clarksville.m' in file /code/experiment/results/plot_syr_m1p_clarksville.m near line 50, column 1

% %%
run plot_syrk_m1p_k1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16

% %%
run plot_trmm_m1p_n1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_trmm_m1p_n1p_clarksville.m' in file /code/experiment/results/plot_trmm_m1p_n1p_clarksville.m near line 50, column 1

% %%
run plot_trmv_m1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_trmv_m1p_clarksville.m' in file /code/experiment/results/plot_trmv_m1p_clarksville.m near line 50, column 1

% %%
run plot_trsv_m1p_clarksville
% Out:
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% warning: ft_render: unable to set font size to 16
% 'export_fig' undefined near line 50 column 1
% error: called from '/code/experiment/results/plot_trsv_m1p_clarksville.m' in file /code/experiment/results/plot_trsv_m1p_clarksville.m near line 50, column 1

% %% [markdown]
% The following cannot be obtained since required files `trsm_blis_nofus_fpu_mxn.m` and `trsm_blis_nofus_sse_4x4.m` are not produced by the re-execution of the experiment

% %%
run plot_trsm_fusing_m1p_n1p_clarksville
% Out:
% run: file SCRIPT must exist and be a valid Octave scriptfile
% error: called from 'run' in file /usr/local/share/octave/4.0.3/m/miscellaneous/run.m near line 58, column 5

% %%
run plot_trsm_fusing_m1p_n1p_speedup_clarksville
% Out:
% 'data_trsm_blis_nofus_sse_4x4' undefined near line 22 column 43
% error: called from '/code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m' in file /code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m near line 22, column 41

% %%
run plot_trsm_fusing_m1p_n1p_speedup_clarksville
% Out:
% 'data_trsm_blis_nofus_sse_4x4' undefined near line 22 column 43
% error: called from '/code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m' in file /code/experiment/results/plot_trsm_fusing_m1p_n1p_speedup_clarksville.m near line 22, column 41
